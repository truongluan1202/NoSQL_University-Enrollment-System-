# %% [markdown]
# # Pre-install
#
# #### Install any necessary library / package if not install

# %%
# Uncomment the following lines to install the required packages
# !pip install psycopg2
# !pip install pandas

# %% [markdown]
# # Pre-define some data

# %%
import psycopg2
import pandas as pd

conn_params = {
    "dbname": "postgres",
    "user": "postgres",
    "password": "12345",
    "host": "localhost",
    "port": "5432",
}

students_data = [
    ("John", "Doe", "Computer Science"),
    ("Jane", "Smith", "Mathematics"),
    ("Emily", "Johnson", "Physics"),
    ("Michael", "Brown", "Engineering"),
    ("Luan", "Tran", "Data Science"),
]

courses_data = [
    ("Introduction to Python", "Computer Science", 2),
    ("Calculus I", "Mathematics", 1),
    ("Physics I", "Physics", 5),
    ("Engineering Design", "Engineering", 3),
]

# %% [markdown]
# # Define some necessary functions

# %% [markdown]
# ### connect to database

# %%
def connect():
    """Establishes a connection to the PostgreSQL database and returns the connection and cursor."""
    try:
        conn = psycopg2.connect(**conn_params)
        cur = conn.cursor()
        print("Connection to PostgreSQL established successfully.")
        return conn, cur
    except OperationalError as e:
        print("The error occurred:", e)
        return None, None


def check_connect(conn, cur):
    assert conn is not None, "Database connection failed!"
    print("Database connection is active.")
    assert cur is not None, "Cursor creation failed!"
    print("Cursor created successfully.")
    return True

# %%
conn, cur = connect()
# Out:
# Connection to PostgreSQL established successfully.

# %%
check_connect(conn, cur)
# Out:
# Database connection is active.
# Cursor created successfully.
# True

# %% [markdown]
# ### display retrieved data as a table with some styling

# %%
def display_df(df):
    styled_df = (
        df.style.set_properties(
            **{
                "text-align": "center",
                "border": "1px solid black",
                "color": "black",
            }  # Set border and text color
        )
        .set_table_styles(
            [  # Set bold header, background color for header, and black text
                {
                    "selector": "th",
                    "props": [
                        ("font-weight", "bold"),
                        ("background-color", "#f2f2f2"),
                        ("color", "black"),  # Ensure header text is black
                    ],
                }
            ]
        )
        .applymap(
            lambda x: "background-color: #f9f9f9", subset=pd.IndexSlice[::2, :]
        )  # Row background color for even rows
        .applymap(
            lambda x: "background-color: #e0e0e0", subset=pd.IndexSlice[1::2, :]
        )  # Row background color for odd rows
    )
    return styled_df

# %% [markdown]
# # Initial Database
#
# ### Feeding some initial data into Students and Courses table

# %%
def precondition():
    try:
        conn, cur = connect()
        check_connect(conn, cur)
        # If the connection is active, proceed with data insertion
        if conn is not None and cur is not None:
            # Insert data into the Students table
            for student in students_data:
                cur.execute(
                    """
                INSERT INTO Students (first_name, last_name, major)
                VALUES (%s, %s, %s)
                """,
                    student,
                )

            # Insert data into the Courses table
            for course in courses_data:
                cur.execute(
                    """
                INSERT INTO Courses (course_name, department, max_capacity)
                VALUES (%s, %s, %s)
                """,
                    course,
                )

            # Commit the transactions to save the data
            conn.commit()
            print("\nData inserted successfully into Students and Courses tables.")

            # Query and display the inserted data to confirm
            cur.execute("SELECT * FROM Students")
            students_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nStudents Table Data:")
            df = pd.DataFrame(students_result, columns=column_names)
            styled_df = display_df(df)
            display(styled_df)

            cur.execute("SELECT * FROM Courses")
            courses_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nCourses Table Data:")
            df = pd.DataFrame(
                courses_result,
                columns=column_names,
            )
            styled_df = display_df(df)
            display(styled_df)

    except AssertionError as e:
        print(e)
    except Exception as e:
        print("\nThe error occurred:", e)
    finally:
        # Ensure the cursor and connection are closed if they were created
        if "cur" in locals() and cur is not None:
            cur.close()
        if "conn" in locals() and conn is not None:
            conn.close()
        print("Connection closed.")


precondition()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Data inserted successfully into Students and Courses tables.
#
# Students Table Data:
# <style type="text/css">
# #T_d0583 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_d0583_row0_col0, #T_d0583_row0_col1, #T_d0583_row0_col2, #T_d0583_row0_col3, #T_d0583_row2_col0, #T_d0583_row2_col1, #T_d0583_row2_col2, #T_d0583_row2_col3, #T_d0583_row4_col0, #T_d0583_row4_col1, #T_d0583_row4_col2, #T_d0583_row4_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_d0583_row1_col0, #T_d0583_row1_col1, #T_d0583_row1_col2, #T_d0583_row1_col3, #T_d0583_row3_col0, #T_d0583_row3_col1, #T_d0583_row3_col2, #T_d0583_row3_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_d0583">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0583_level0_col0" class="col_heading level0 col0" >student_id</th>
#       <th id="T_d0583_level0_col1" class="col_heading level0 col1" >first_name</th>
#       <th id="T_d0583_level0_col2" class="col_heading level0 col2" >last_name</th>
#       <th id="T_d0583_level0_col3" class="col_heading level0 col3" >major</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0583_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0583_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d0583_row0_col1" class="data row0 col1" >John</td>
#       <td id="T_d0583_row0_col2" class="data row0 col2" >Doe</td>
#       <td id="T_d0583_row0_col3" class="data row0 col3" >Computer Science</td>
#     </tr>
#     <tr>
#       <th id="T_d0583_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0583_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d0583_row1_col1" class="data row1 col1" >Jane</td>
#       <td id="T_d0583_row1_col2" class="data row1 col2" >Smith</td>
#       <td id="T_d0583_row1_col3" class="data row1 col3" >Mathematics</td>
#     </tr>
#     <tr>
#       <th id="T_d0583_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0583_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d0583_row2_col1" class="data row2 col1" >Emily</td>
#       <td id="T_d0583_row2_col2" class="data row2 col2" >Johnson</td>
#       <td id="T_d0583_row2_col3" class="data row2 col3" >Physics</td>
#     </tr>
#     <tr>
#       <th id="T_d0583_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0583_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d0583_row3_col1" class="data row3 col1" >Michael</td>
#       <td id="T_d0583_row3_col2" class="data row3 col2" >Brown</td>
#       <td id="T_d0583_row3_col3" class="data row3 col3" >Engineering</td>
#     </tr>
#     <tr>
#       <th id="T_d0583_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0583_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_d0583_row4_col1" class="data row4 col1" >Luan</td>
#       <td id="T_d0583_row4_col2" class="data row4 col2" >Tran</td>
#       <td id="T_d0583_row4_col3" class="data row4 col3" >Data Science</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_7d8ee th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_7d8ee_row0_col0, #T_7d8ee_row0_col1, #T_7d8ee_row0_col2, #T_7d8ee_row0_col3, #T_7d8ee_row0_col4, #T_7d8ee_row2_col0, #T_7d8ee_row2_col1, #T_7d8ee_row2_col2, #T_7d8ee_row2_col3, #T_7d8ee_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_7d8ee_row1_col0, #T_7d8ee_row1_col1, #T_7d8ee_row1_col2, #T_7d8ee_row1_col3, #T_7d8ee_row1_col4, #T_7d8ee_row3_col0, #T_7d8ee_row3_col1, #T_7d8ee_row3_col2, #T_7d8ee_row3_col3, #T_7d8ee_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_7d8ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d8ee_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_7d8ee_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_7d8ee_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_7d8ee_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_7d8ee_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d8ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d8ee_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7d8ee_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_7d8ee_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_7d8ee_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_7d8ee_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7d8ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d8ee_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7d8ee_row1_col1" class="data row1 col1" >Calculus I</td>
#       <td id="T_7d8ee_row1_col2" class="data row1 col2" >Mathematics</td>
#       <td id="T_7d8ee_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_7d8ee_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7d8ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d8ee_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7d8ee_row2_col1" class="data row2 col1" >Physics I</td>
#       <td id="T_7d8ee_row2_col2" class="data row2 col2" >Physics</td>
#       <td id="T_7d8ee_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_7d8ee_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7d8ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d8ee_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_7d8ee_row3_col1" class="data row3 col1" >Engineering Design</td>
#       <td id="T_7d8ee_row3_col2" class="data row3 col2" >Engineering</td>
#       <td id="T_7d8ee_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_7d8ee_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# # Calling Stored Procedure

# %%
def query_stored_procedure_enroll_student(student_id=None, course_id=None):
    # Prompt for student ID and course ID
    if student_id is None:
        student_id = input("Enter the student ID: ")
    if course_id is None:
        course_id = input("Enter the course ID: ")
    try:
        conn, cur = connect()
        check_connect(conn, cur)
        # If the connection is active, proceed with data insertion
        if conn is not None and cur is not None:
            # Enroll the student in the course
            cur.execute(
                """
            CALL enrollstudent(%s, %s)
            """,
                (student_id, course_id),
            )
            conn.commit()
            print("Student enrolled successfully in the course.")

            # Query and display the updated data to confirm
            cur.execute("SELECT * FROM Enrollments")
            enrollments_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nEnrollments Table Data:")
            df = pd.DataFrame(
                enrollments_result,
                columns=column_names,
            )

            styled_df = display_df(df)
            display(styled_df)

    except AssertionError as e:
        print(e)
    except Exception as e:
        print("\nThe error occurred:", e)
    finally:
        # Ensure the cursor and connection are closed if they were created
        if "cur" in locals() and cur is not None:
            cur.close()
        if "conn" in locals() and conn is not None:
            conn.close()
        print("Connection closed.\n")

# %%
query_stored_procedure_enroll_student()
# Out:
# Enter the student ID: 5
# Enter the course ID: 3
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
# Student enrolled successfully in the course.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_f54a2 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_f54a2_row0_col0, #T_f54a2_row0_col1, #T_f54a2_row0_col2, #T_f54a2_row0_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# </style>
# <table id="T_f54a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f54a2_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_f54a2_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_f54a2_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_f54a2_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f54a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f54a2_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f54a2_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_f54a2_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_f54a2_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %%
query_stored_procedure_enroll_student(1, 3)
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
# Student enrolled successfully in the course.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_922b9 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_922b9_row0_col0, #T_922b9_row0_col1, #T_922b9_row0_col2, #T_922b9_row0_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_922b9_row1_col0, #T_922b9_row1_col1, #T_922b9_row1_col2, #T_922b9_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_922b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_922b9_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_922b9_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_922b9_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_922b9_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_922b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_922b9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_922b9_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_922b9_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_922b9_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_922b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_922b9_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_922b9_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_922b9_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_922b9_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# # Querrying the Views

# %%
def query_views():
    try:
        conn, cur = connect()
        check_connect(conn, cur)
        # If the connection is active, proceed with data insertion
        if conn is not None and cur is not None:
            # Query and display the view data
            cur.execute("SELECT * FROM StudentCourseView")
            student_courses_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nStudentCourses View Data:")
            df = pd.DataFrame(
                student_courses_result,
                columns=column_names,
            )
            styled_df = display_df(df)
            display(styled_df)

            cur.execute("SELECT * FROM CourseCapacityView")
            course_capacity_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nCourseCapacity View Data:")
            df = pd.DataFrame(
                course_capacity_result,
                columns=column_names,
            )
            styled_df = display_df(df)
            display(styled_df)

    except AssertionError as e:
        print(e)
    except Exception as e:
        print("\nThe error occurred:", e)
    finally:
        # Ensure the cursor and connection are closed if they were created
        if "cur" in locals() and cur is not None:
            cur.close()
        if "conn" in locals() and conn is not None:
            conn.close()
        print("Connection closed.\n")


query_views()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# StudentCourses View Data:
# <style type="text/css">
# #T_3bc02 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_3bc02_row0_col0, #T_3bc02_row0_col1, #T_3bc02_row0_col2, #T_3bc02_row0_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_3bc02_row1_col0, #T_3bc02_row1_col1, #T_3bc02_row1_col2, #T_3bc02_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_3bc02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bc02_level0_col0" class="col_heading level0 col0" >student_id</th>
#       <th id="T_3bc02_level0_col1" class="col_heading level0 col1" >student_name</th>
#       <th id="T_3bc02_level0_col2" class="col_heading level0 col2" >course_name</th>
#       <th id="T_3bc02_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bc02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3bc02_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_3bc02_row0_col1" class="data row0 col1" >Luan Tran</td>
#       <td id="T_3bc02_row0_col2" class="data row0 col2" >Physics I</td>
#       <td id="T_3bc02_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_3bc02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3bc02_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_3bc02_row1_col1" class="data row1 col1" >John Doe</td>
#       <td id="T_3bc02_row1_col2" class="data row1 col2" >Physics I</td>
#       <td id="T_3bc02_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#   </tbody>
# </table>
# CourseCapacity View Data:
# <style type="text/css">
# #T_dae20 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_dae20_row0_col0, #T_dae20_row0_col1, #T_dae20_row0_col2, #T_dae20_row0_col3, #T_dae20_row0_col4, #T_dae20_row2_col0, #T_dae20_row2_col1, #T_dae20_row2_col2, #T_dae20_row2_col3, #T_dae20_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_dae20_row1_col0, #T_dae20_row1_col1, #T_dae20_row1_col2, #T_dae20_row1_col3, #T_dae20_row1_col4, #T_dae20_row3_col0, #T_dae20_row3_col1, #T_dae20_row3_col2, #T_dae20_row3_col3, #T_dae20_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_dae20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dae20_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_dae20_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_dae20_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_dae20_level0_col3" class="col_heading level0 col3" >current_enrollment</th>
#       <th id="T_dae20_level0_col4" class="col_heading level0 col4" >remaining_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dae20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dae20_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_dae20_row0_col1" class="data row0 col1" >Engineering Design</td>
#       <td id="T_dae20_row0_col2" class="data row0 col2" >Engineering</td>
#       <td id="T_dae20_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_dae20_row0_col4" class="data row0 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dae20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dae20_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_dae20_row1_col1" class="data row1 col1" >Calculus I</td>
#       <td id="T_dae20_row1_col2" class="data row1 col2" >Mathematics</td>
#       <td id="T_dae20_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_dae20_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_dae20_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dae20_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_dae20_row2_col1" class="data row2 col1" >Introduction to Python</td>
#       <td id="T_dae20_row2_col2" class="data row2 col2" >Computer Science</td>
#       <td id="T_dae20_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_dae20_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dae20_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dae20_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_dae20_row3_col1" class="data row3 col1" >Physics I</td>
#       <td id="T_dae20_row3_col2" class="data row3 col2" >Physics</td>
#       <td id="T_dae20_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_dae20_row3_col4" class="data row3 col4" >3</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# # Triggering Events

# %%
def trigger_event(student_id, course_id, action="enroll"):
    try:
        conn, cur = connect()
        check_connect(conn, cur)
        # If the connection is active, proceed with data insertion
        if conn is not None and cur is not None:
            # Enroll or drop the student from the course based on the action
            if action == "enroll":
                cur.execute("""CALL enrollstudent(%s, %s)""", (student_id, course_id))
                print("Student enrolled successfully in the course.")
            elif action == "drop":
                # Check if the record exists before attempting to delete
                cur.execute(
                    """
                    SELECT 1 FROM Enrollments
                    WHERE student_id = %s AND course_id = %s
                    """,
                    (student_id, course_id),
                )
                if cur.fetchone():
                    cur.execute(
                        """
                        DELETE FROM Enrollments
                        WHERE student_id = %s AND course_id = %s
                        """,
                        (student_id, course_id),
                    )
                    print("Student dropped successfully from the course.")
                else:
                    raise Exception("The student is not enrolled in the course.")

            conn.commit()

            # Query and display the updated data to confirm
            cur.execute("SELECT * FROM EnrollmentLog")
            enrollment_log_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("Check the updated enrollment log after the event:")
            print("\nEnrollmentLog Table Data:")
            df = pd.DataFrame(
                enrollment_log_result,
                columns=column_names,
            )
            styled_df = display_df(df)
            display(styled_df)

            cur.execute("SELECT * FROM Courses")
            courses_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("Check the updated course capacity after the event:")
            print("\nCourses Table Data:")
            df = pd.DataFrame(
                courses_result,
                columns=column_names,
            )
            styled_df = display_df(df)
            display(styled_df)

    except AssertionError as e:
        print(e)
    except Exception as e:
        print("\nThe error occurred:", e)
    finally:
        # Ensure the cursor and connection are closed if they were created
        if "cur" in locals() and cur is not None:
            cur.close()
        if "conn" in locals() and conn is not None:
            conn.close()
        print("Connection closed.\n")

# %%
trigger_event(3, 3, "enroll")
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
# Student enrolled successfully in the course.
# Check the updated enrollment log after the event:
#
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_a1832 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_a1832_row0_col0, #T_a1832_row0_col1, #T_a1832_row0_col2, #T_a1832_row0_col3, #T_a1832_row0_col4, #T_a1832_row2_col0, #T_a1832_row2_col1, #T_a1832_row2_col2, #T_a1832_row2_col3, #T_a1832_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_a1832_row1_col0, #T_a1832_row1_col1, #T_a1832_row1_col2, #T_a1832_row1_col3, #T_a1832_row1_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_a1832">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1832_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_a1832_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_a1832_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_a1832_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_a1832_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1832_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1832_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a1832_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_a1832_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_a1832_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_a1832_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_a1832_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1832_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a1832_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_a1832_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_a1832_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_a1832_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_a1832_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1832_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a1832_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_a1832_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_a1832_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_a1832_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#   </tbody>
# </table>
# Check the updated course capacity after the event:
#
# Courses Table Data:
# <style type="text/css">
# #T_70cee th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_70cee_row0_col0, #T_70cee_row0_col1, #T_70cee_row0_col2, #T_70cee_row0_col3, #T_70cee_row0_col4, #T_70cee_row2_col0, #T_70cee_row2_col1, #T_70cee_row2_col2, #T_70cee_row2_col3, #T_70cee_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_70cee_row1_col0, #T_70cee_row1_col1, #T_70cee_row1_col2, #T_70cee_row1_col3, #T_70cee_row1_col4, #T_70cee_row3_col0, #T_70cee_row3_col1, #T_70cee_row3_col2, #T_70cee_row3_col3, #T_70cee_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_70cee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70cee_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_70cee_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_70cee_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_70cee_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_70cee_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70cee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70cee_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_70cee_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_70cee_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_70cee_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_70cee_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_70cee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70cee_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_70cee_row1_col1" class="data row1 col1" >Calculus I</td>
#       <td id="T_70cee_row1_col2" class="data row1 col2" >Mathematics</td>
#       <td id="T_70cee_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_70cee_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_70cee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_70cee_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_70cee_row2_col1" class="data row2 col1" >Engineering Design</td>
#       <td id="T_70cee_row2_col2" class="data row2 col2" >Engineering</td>
#       <td id="T_70cee_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_70cee_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_70cee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_70cee_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_70cee_row3_col1" class="data row3 col1" >Physics I</td>
#       <td id="T_70cee_row3_col2" class="data row3 col2" >Physics</td>
#       <td id="T_70cee_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_70cee_row3_col4" class="data row3 col4" >3</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %%
trigger_event(3, 3, "drop")
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
# Student dropped successfully from the course.
# Check the updated enrollment log after the event:
#
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_1080d th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_1080d_row0_col0, #T_1080d_row0_col1, #T_1080d_row0_col2, #T_1080d_row0_col3, #T_1080d_row0_col4, #T_1080d_row2_col0, #T_1080d_row2_col1, #T_1080d_row2_col2, #T_1080d_row2_col3, #T_1080d_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_1080d_row1_col0, #T_1080d_row1_col1, #T_1080d_row1_col2, #T_1080d_row1_col3, #T_1080d_row1_col4, #T_1080d_row3_col0, #T_1080d_row3_col1, #T_1080d_row3_col2, #T_1080d_row3_col3, #T_1080d_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_1080d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1080d_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_1080d_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_1080d_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_1080d_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_1080d_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1080d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1080d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1080d_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_1080d_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_1080d_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_1080d_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_1080d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1080d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_1080d_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_1080d_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_1080d_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_1080d_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_1080d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1080d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_1080d_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_1080d_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_1080d_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_1080d_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_1080d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1080d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_1080d_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_1080d_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_1080d_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_1080d_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#   </tbody>
# </table>
# Check the updated course capacity after the event:
#
# Courses Table Data:
# <style type="text/css">
# #T_970bf th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_970bf_row0_col0, #T_970bf_row0_col1, #T_970bf_row0_col2, #T_970bf_row0_col3, #T_970bf_row0_col4, #T_970bf_row2_col0, #T_970bf_row2_col1, #T_970bf_row2_col2, #T_970bf_row2_col3, #T_970bf_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_970bf_row1_col0, #T_970bf_row1_col1, #T_970bf_row1_col2, #T_970bf_row1_col3, #T_970bf_row1_col4, #T_970bf_row3_col0, #T_970bf_row3_col1, #T_970bf_row3_col2, #T_970bf_row3_col3, #T_970bf_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_970bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_970bf_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_970bf_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_970bf_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_970bf_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_970bf_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_970bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_970bf_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_970bf_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_970bf_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_970bf_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_970bf_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_970bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_970bf_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_970bf_row1_col1" class="data row1 col1" >Calculus I</td>
#       <td id="T_970bf_row1_col2" class="data row1 col2" >Mathematics</td>
#       <td id="T_970bf_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_970bf_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_970bf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_970bf_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_970bf_row2_col1" class="data row2 col1" >Engineering Design</td>
#       <td id="T_970bf_row2_col2" class="data row2 col2" >Engineering</td>
#       <td id="T_970bf_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_970bf_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_970bf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_970bf_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_970bf_row3_col1" class="data row3 col1" >Physics I</td>
#       <td id="T_970bf_row3_col2" class="data row3 col2" >Physics</td>
#       <td id="T_970bf_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_970bf_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# # Test Case

# %% [markdown]
# ### Our current database is showned below

# %%
def current_database():
    try:
        conn, cur = connect()
        check_connect(conn, cur)
        # If the connection is active, proceed with data insertion
        if conn is not None and cur is not None:
            # Query and display the inserted data to confirm

            # Students Table Data
            cur.execute("SELECT * FROM Students")
            students_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nStudents Table Data:")
            df = pd.DataFrame(students_result, columns=column_names)
            styled_df = display_df(df)
            display(styled_df)

            # Courses Table Data
            cur.execute("SELECT * FROM Courses")
            courses_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nCourses Table Data:")
            df = pd.DataFrame(
                courses_result,
                columns=column_names,
            )
            styled_df = display_df(df)
            display(styled_df)

    except AssertionError as e:
        print(e)
    except Exception as e:
        print("The error occurred:", e)
    finally:
        # Ensure the cursor and connection are closed if they were created
        if "cur" in locals() and cur is not None:
            cur.close()
        if "conn" in locals() and conn is not None:
            conn.close()
        print("Connection closed.")


current_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Students Table Data:
# <style type="text/css">
# #T_edcc0 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_edcc0_row0_col0, #T_edcc0_row0_col1, #T_edcc0_row0_col2, #T_edcc0_row0_col3, #T_edcc0_row2_col0, #T_edcc0_row2_col1, #T_edcc0_row2_col2, #T_edcc0_row2_col3, #T_edcc0_row4_col0, #T_edcc0_row4_col1, #T_edcc0_row4_col2, #T_edcc0_row4_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_edcc0_row1_col0, #T_edcc0_row1_col1, #T_edcc0_row1_col2, #T_edcc0_row1_col3, #T_edcc0_row3_col0, #T_edcc0_row3_col1, #T_edcc0_row3_col2, #T_edcc0_row3_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_edcc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edcc0_level0_col0" class="col_heading level0 col0" >student_id</th>
#       <th id="T_edcc0_level0_col1" class="col_heading level0 col1" >first_name</th>
#       <th id="T_edcc0_level0_col2" class="col_heading level0 col2" >last_name</th>
#       <th id="T_edcc0_level0_col3" class="col_heading level0 col3" >major</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edcc0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edcc0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_edcc0_row0_col1" class="data row0 col1" >John</td>
#       <td id="T_edcc0_row0_col2" class="data row0 col2" >Doe</td>
#       <td id="T_edcc0_row0_col3" class="data row0 col3" >Computer Science</td>
#     </tr>
#     <tr>
#       <th id="T_edcc0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edcc0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_edcc0_row1_col1" class="data row1 col1" >Jane</td>
#       <td id="T_edcc0_row1_col2" class="data row1 col2" >Smith</td>
#       <td id="T_edcc0_row1_col3" class="data row1 col3" >Mathematics</td>
#     </tr>
#     <tr>
#       <th id="T_edcc0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edcc0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_edcc0_row2_col1" class="data row2 col1" >Emily</td>
#       <td id="T_edcc0_row2_col2" class="data row2 col2" >Johnson</td>
#       <td id="T_edcc0_row2_col3" class="data row2 col3" >Physics</td>
#     </tr>
#     <tr>
#       <th id="T_edcc0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edcc0_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_edcc0_row3_col1" class="data row3 col1" >Michael</td>
#       <td id="T_edcc0_row3_col2" class="data row3 col2" >Brown</td>
#       <td id="T_edcc0_row3_col3" class="data row3 col3" >Engineering</td>
#     </tr>
#     <tr>
#       <th id="T_edcc0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edcc0_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_edcc0_row4_col1" class="data row4 col1" >Luan</td>
#       <td id="T_edcc0_row4_col2" class="data row4 col2" >Tran</td>
#       <td id="T_edcc0_row4_col3" class="data row4 col3" >Data Science</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_4e3b2 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_4e3b2_row0_col0, #T_4e3b2_row0_col1, #T_4e3b2_row0_col2, #T_4e3b2_row0_col3, #T_4e3b2_row0_col4, #T_4e3b2_row2_col0, #T_4e3b2_row2_col1, #T_4e3b2_row2_col2, #T_4e3b2_row2_col3, #T_4e3b2_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_4e3b2_row1_col0, #T_4e3b2_row1_col1, #T_4e3b2_row1_col2, #T_4e3b2_row1_col3, #T_4e3b2_row1_col4, #T_4e3b2_row3_col0, #T_4e3b2_row3_col1, #T_4e3b2_row3_col2, #T_4e3b2_row3_col3, #T_4e3b2_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_4e3b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e3b2_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_4e3b2_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_4e3b2_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_4e3b2_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_4e3b2_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e3b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e3b2_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4e3b2_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_4e3b2_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_4e3b2_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_4e3b2_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4e3b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e3b2_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4e3b2_row1_col1" class="data row1 col1" >Calculus I</td>
#       <td id="T_4e3b2_row1_col2" class="data row1 col2" >Mathematics</td>
#       <td id="T_4e3b2_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_4e3b2_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4e3b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e3b2_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_4e3b2_row2_col1" class="data row2 col1" >Engineering Design</td>
#       <td id="T_4e3b2_row2_col2" class="data row2 col2" >Engineering</td>
#       <td id="T_4e3b2_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_4e3b2_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4e3b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4e3b2_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_4e3b2_row3_col1" class="data row3 col1" >Physics I</td>
#       <td id="T_4e3b2_row3_col2" class="data row3 col2" >Physics</td>
#       <td id="T_4e3b2_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_4e3b2_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# ### current tracking table

# %%
def track_database():
    try:
        conn, cur = connect()
        check_connect(conn, cur)
        # If the connection is active, proceed with data insertion
        if conn is not None and cur is not None:
            # Query and display the inserted data to confirm

            # Enrollments Table Data
            cur.execute("SELECT * FROM Enrollments")
            enrollments_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nEnrollments Table Data:")
            df = pd.DataFrame(enrollments_result, columns=column_names)
            styled_df = display_df(df)
            display(styled_df)

            # Courses Table Data
            cur.execute("SELECT * FROM Courses")
            courses_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nCourses Table Data:")
            df = pd.DataFrame(
                courses_result,
                columns=column_names,
            )
            styled_df = display_df(df)
            display(styled_df)

            # EnrollmentLog Table Data
            cur.execute("SELECT * FROM EnrollmentLog")
            enrollment_log_result = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("\nEnrollmentLog Table Data:")
            df = pd.DataFrame(
                enrollment_log_result,
                columns=column_names,
            )
            styled_df = display_df(df)
            display(styled_df)

    except AssertionError as e:
        print(e)
    except Exception as e:
        print("The error occurred:", e)
    finally:
        # Ensure the cursor and connection are closed if they were created
        if "cur" in locals() and cur is not None:
            cur.close()
        if "conn" in locals() and conn is not None:
            conn.close()
        print("Connection closed.")


track_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_1c1a8 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_1c1a8_row0_col0, #T_1c1a8_row0_col1, #T_1c1a8_row0_col2, #T_1c1a8_row0_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_1c1a8_row1_col0, #T_1c1a8_row1_col1, #T_1c1a8_row1_col2, #T_1c1a8_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_1c1a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c1a8_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_1c1a8_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_1c1a8_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_1c1a8_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c1a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c1a8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1c1a8_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_1c1a8_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_1c1a8_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_1c1a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1c1a8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_1c1a8_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_1c1a8_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_1c1a8_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_6ac67 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_6ac67_row0_col0, #T_6ac67_row0_col1, #T_6ac67_row0_col2, #T_6ac67_row0_col3, #T_6ac67_row0_col4, #T_6ac67_row2_col0, #T_6ac67_row2_col1, #T_6ac67_row2_col2, #T_6ac67_row2_col3, #T_6ac67_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_6ac67_row1_col0, #T_6ac67_row1_col1, #T_6ac67_row1_col2, #T_6ac67_row1_col3, #T_6ac67_row1_col4, #T_6ac67_row3_col0, #T_6ac67_row3_col1, #T_6ac67_row3_col2, #T_6ac67_row3_col3, #T_6ac67_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_6ac67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ac67_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_6ac67_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_6ac67_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_6ac67_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_6ac67_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ac67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ac67_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6ac67_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_6ac67_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_6ac67_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_6ac67_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ac67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ac67_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6ac67_row1_col1" class="data row1 col1" >Calculus I</td>
#       <td id="T_6ac67_row1_col2" class="data row1 col2" >Mathematics</td>
#       <td id="T_6ac67_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_6ac67_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ac67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ac67_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_6ac67_row2_col1" class="data row2 col1" >Engineering Design</td>
#       <td id="T_6ac67_row2_col2" class="data row2 col2" >Engineering</td>
#       <td id="T_6ac67_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_6ac67_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6ac67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ac67_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_6ac67_row3_col1" class="data row3 col1" >Physics I</td>
#       <td id="T_6ac67_row3_col2" class="data row3 col2" >Physics</td>
#       <td id="T_6ac67_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_6ac67_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#   </tbody>
# </table>
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_86e9f th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_86e9f_row0_col0, #T_86e9f_row0_col1, #T_86e9f_row0_col2, #T_86e9f_row0_col3, #T_86e9f_row0_col4, #T_86e9f_row2_col0, #T_86e9f_row2_col1, #T_86e9f_row2_col2, #T_86e9f_row2_col3, #T_86e9f_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_86e9f_row1_col0, #T_86e9f_row1_col1, #T_86e9f_row1_col2, #T_86e9f_row1_col3, #T_86e9f_row1_col4, #T_86e9f_row3_col0, #T_86e9f_row3_col1, #T_86e9f_row3_col2, #T_86e9f_row3_col3, #T_86e9f_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_86e9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86e9f_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_86e9f_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_86e9f_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_86e9f_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_86e9f_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86e9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86e9f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_86e9f_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_86e9f_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_86e9f_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_86e9f_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_86e9f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86e9f_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_86e9f_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_86e9f_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_86e9f_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_86e9f_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_86e9f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86e9f_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_86e9f_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_86e9f_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_86e9f_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_86e9f_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_86e9f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86e9f_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_86e9f_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_86e9f_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_86e9f_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_86e9f_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# ### Test case 1 : Course is full

# %% [markdown]
# enrollStudent(5, 2) make the course full

# %%
query_stored_procedure_enroll_student(5, 2)
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
# Student enrolled successfully in the course.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_c56a6 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_c56a6_row0_col0, #T_c56a6_row0_col1, #T_c56a6_row0_col2, #T_c56a6_row0_col3, #T_c56a6_row2_col0, #T_c56a6_row2_col1, #T_c56a6_row2_col2, #T_c56a6_row2_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_c56a6_row1_col0, #T_c56a6_row1_col1, #T_c56a6_row1_col2, #T_c56a6_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_c56a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c56a6_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_c56a6_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_c56a6_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_c56a6_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c56a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c56a6_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c56a6_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_c56a6_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_c56a6_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_c56a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c56a6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c56a6_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_c56a6_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_c56a6_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_c56a6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c56a6_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_c56a6_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_c56a6_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_c56a6_row2_col3" class="data row2 col3" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# Try doing enrollStudent(4, 2)

# %%
query_stored_procedure_enroll_student(4, 2)
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# The error occurred: Course is full
# CONTEXT:  PL/pgSQL function enrollstudent(integer,integer) line 40 at RAISE
#
# Connection closed.

# %% [markdown]
# Checking any changes in database

# %%
track_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_84eb6 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_84eb6_row0_col0, #T_84eb6_row0_col1, #T_84eb6_row0_col2, #T_84eb6_row0_col3, #T_84eb6_row2_col0, #T_84eb6_row2_col1, #T_84eb6_row2_col2, #T_84eb6_row2_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_84eb6_row1_col0, #T_84eb6_row1_col1, #T_84eb6_row1_col2, #T_84eb6_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_84eb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84eb6_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_84eb6_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_84eb6_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_84eb6_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84eb6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84eb6_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_84eb6_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_84eb6_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_84eb6_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_84eb6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84eb6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_84eb6_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_84eb6_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_84eb6_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_84eb6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84eb6_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_84eb6_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_84eb6_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_84eb6_row2_col3" class="data row2 col3" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_b7a07 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_b7a07_row0_col0, #T_b7a07_row0_col1, #T_b7a07_row0_col2, #T_b7a07_row0_col3, #T_b7a07_row0_col4, #T_b7a07_row2_col0, #T_b7a07_row2_col1, #T_b7a07_row2_col2, #T_b7a07_row2_col3, #T_b7a07_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_b7a07_row1_col0, #T_b7a07_row1_col1, #T_b7a07_row1_col2, #T_b7a07_row1_col3, #T_b7a07_row1_col4, #T_b7a07_row3_col0, #T_b7a07_row3_col1, #T_b7a07_row3_col2, #T_b7a07_row3_col3, #T_b7a07_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_b7a07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7a07_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_b7a07_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_b7a07_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_b7a07_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_b7a07_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7a07_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7a07_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b7a07_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_b7a07_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_b7a07_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_b7a07_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b7a07_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b7a07_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_b7a07_row1_col1" class="data row1 col1" >Engineering Design</td>
#       <td id="T_b7a07_row1_col2" class="data row1 col2" >Engineering</td>
#       <td id="T_b7a07_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_b7a07_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b7a07_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b7a07_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_b7a07_row2_col1" class="data row2 col1" >Physics I</td>
#       <td id="T_b7a07_row2_col2" class="data row2 col2" >Physics</td>
#       <td id="T_b7a07_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_b7a07_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b7a07_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b7a07_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_b7a07_row3_col1" class="data row3 col1" >Calculus I</td>
#       <td id="T_b7a07_row3_col2" class="data row3 col2" >Mathematics</td>
#       <td id="T_b7a07_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_b7a07_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_66f5b th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_66f5b_row0_col0, #T_66f5b_row0_col1, #T_66f5b_row0_col2, #T_66f5b_row0_col3, #T_66f5b_row0_col4, #T_66f5b_row2_col0, #T_66f5b_row2_col1, #T_66f5b_row2_col2, #T_66f5b_row2_col3, #T_66f5b_row2_col4, #T_66f5b_row4_col0, #T_66f5b_row4_col1, #T_66f5b_row4_col2, #T_66f5b_row4_col3, #T_66f5b_row4_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_66f5b_row1_col0, #T_66f5b_row1_col1, #T_66f5b_row1_col2, #T_66f5b_row1_col3, #T_66f5b_row1_col4, #T_66f5b_row3_col0, #T_66f5b_row3_col1, #T_66f5b_row3_col2, #T_66f5b_row3_col3, #T_66f5b_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_66f5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66f5b_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_66f5b_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_66f5b_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_66f5b_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_66f5b_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66f5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66f5b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_66f5b_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_66f5b_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_66f5b_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_66f5b_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_66f5b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66f5b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_66f5b_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_66f5b_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_66f5b_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_66f5b_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_66f5b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66f5b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_66f5b_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_66f5b_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_66f5b_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_66f5b_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_66f5b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66f5b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_66f5b_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_66f5b_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_66f5b_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_66f5b_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#     <tr>
#       <th id="T_66f5b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66f5b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_66f5b_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_66f5b_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_66f5b_row4_col3" class="data row4 col3" >enroll</td>
#       <td id="T_66f5b_row4_col4" class="data row4 col4" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# ### Test case 2 : Course does not exist

# %%
query_stored_procedure_enroll_student(1, 10)
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# The error occurred: Course does not exist
# CONTEXT:  PL/pgSQL function enrollstudent(integer,integer) line 23 at RAISE
#
# Connection closed.

# %% [markdown]
# Checking any changes in database

# %%
track_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_37bc7 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_37bc7_row0_col0, #T_37bc7_row0_col1, #T_37bc7_row0_col2, #T_37bc7_row0_col3, #T_37bc7_row2_col0, #T_37bc7_row2_col1, #T_37bc7_row2_col2, #T_37bc7_row2_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_37bc7_row1_col0, #T_37bc7_row1_col1, #T_37bc7_row1_col2, #T_37bc7_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_37bc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37bc7_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_37bc7_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_37bc7_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_37bc7_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37bc7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37bc7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_37bc7_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_37bc7_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_37bc7_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_37bc7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37bc7_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_37bc7_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_37bc7_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_37bc7_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_37bc7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_37bc7_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_37bc7_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_37bc7_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_37bc7_row2_col3" class="data row2 col3" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_c6b5d th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_c6b5d_row0_col0, #T_c6b5d_row0_col1, #T_c6b5d_row0_col2, #T_c6b5d_row0_col3, #T_c6b5d_row0_col4, #T_c6b5d_row2_col0, #T_c6b5d_row2_col1, #T_c6b5d_row2_col2, #T_c6b5d_row2_col3, #T_c6b5d_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_c6b5d_row1_col0, #T_c6b5d_row1_col1, #T_c6b5d_row1_col2, #T_c6b5d_row1_col3, #T_c6b5d_row1_col4, #T_c6b5d_row3_col0, #T_c6b5d_row3_col1, #T_c6b5d_row3_col2, #T_c6b5d_row3_col3, #T_c6b5d_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_c6b5d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6b5d_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_c6b5d_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_c6b5d_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_c6b5d_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_c6b5d_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6b5d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6b5d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c6b5d_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_c6b5d_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_c6b5d_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_c6b5d_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c6b5d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6b5d_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_c6b5d_row1_col1" class="data row1 col1" >Engineering Design</td>
#       <td id="T_c6b5d_row1_col2" class="data row1 col2" >Engineering</td>
#       <td id="T_c6b5d_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_c6b5d_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c6b5d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6b5d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c6b5d_row2_col1" class="data row2 col1" >Physics I</td>
#       <td id="T_c6b5d_row2_col2" class="data row2 col2" >Physics</td>
#       <td id="T_c6b5d_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_c6b5d_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c6b5d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c6b5d_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_c6b5d_row3_col1" class="data row3 col1" >Calculus I</td>
#       <td id="T_c6b5d_row3_col2" class="data row3 col2" >Mathematics</td>
#       <td id="T_c6b5d_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_c6b5d_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_d2498 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_d2498_row0_col0, #T_d2498_row0_col1, #T_d2498_row0_col2, #T_d2498_row0_col3, #T_d2498_row0_col4, #T_d2498_row2_col0, #T_d2498_row2_col1, #T_d2498_row2_col2, #T_d2498_row2_col3, #T_d2498_row2_col4, #T_d2498_row4_col0, #T_d2498_row4_col1, #T_d2498_row4_col2, #T_d2498_row4_col3, #T_d2498_row4_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_d2498_row1_col0, #T_d2498_row1_col1, #T_d2498_row1_col2, #T_d2498_row1_col3, #T_d2498_row1_col4, #T_d2498_row3_col0, #T_d2498_row3_col1, #T_d2498_row3_col2, #T_d2498_row3_col3, #T_d2498_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_d2498">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2498_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_d2498_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_d2498_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_d2498_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_d2498_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2498_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2498_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d2498_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_d2498_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_d2498_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_d2498_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_d2498_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2498_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d2498_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_d2498_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_d2498_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_d2498_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_d2498_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2498_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d2498_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_d2498_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_d2498_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_d2498_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_d2498_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2498_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d2498_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_d2498_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_d2498_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_d2498_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#     <tr>
#       <th id="T_d2498_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2498_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_d2498_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_d2498_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_d2498_row4_col3" class="data row4 col3" >enroll</td>
#       <td id="T_d2498_row4_col4" class="data row4 col4" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# ### Test case 3 : Student does not exist

# %%
query_stored_procedure_enroll_student(6, 1)
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# The error occurred: Student does not exist
# CONTEXT:  PL/pgSQL function enrollstudent(integer,integer) line 14 at RAISE
#
# Connection closed.

# %% [markdown]
# Checking any changes in database

# %%
track_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_ddbaa th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_ddbaa_row0_col0, #T_ddbaa_row0_col1, #T_ddbaa_row0_col2, #T_ddbaa_row0_col3, #T_ddbaa_row2_col0, #T_ddbaa_row2_col1, #T_ddbaa_row2_col2, #T_ddbaa_row2_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_ddbaa_row1_col0, #T_ddbaa_row1_col1, #T_ddbaa_row1_col2, #T_ddbaa_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_ddbaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddbaa_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_ddbaa_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_ddbaa_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_ddbaa_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddbaa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ddbaa_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ddbaa_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_ddbaa_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_ddbaa_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_ddbaa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ddbaa_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ddbaa_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_ddbaa_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_ddbaa_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_ddbaa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ddbaa_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_ddbaa_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_ddbaa_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_ddbaa_row2_col3" class="data row2 col3" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_0b920 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_0b920_row0_col0, #T_0b920_row0_col1, #T_0b920_row0_col2, #T_0b920_row0_col3, #T_0b920_row0_col4, #T_0b920_row2_col0, #T_0b920_row2_col1, #T_0b920_row2_col2, #T_0b920_row2_col3, #T_0b920_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_0b920_row1_col0, #T_0b920_row1_col1, #T_0b920_row1_col2, #T_0b920_row1_col3, #T_0b920_row1_col4, #T_0b920_row3_col0, #T_0b920_row3_col1, #T_0b920_row3_col2, #T_0b920_row3_col3, #T_0b920_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_0b920">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b920_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_0b920_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_0b920_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_0b920_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_0b920_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b920_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b920_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0b920_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_0b920_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_0b920_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_0b920_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0b920_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0b920_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_0b920_row1_col1" class="data row1 col1" >Engineering Design</td>
#       <td id="T_0b920_row1_col2" class="data row1 col2" >Engineering</td>
#       <td id="T_0b920_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_0b920_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0b920_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0b920_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_0b920_row2_col1" class="data row2 col1" >Physics I</td>
#       <td id="T_0b920_row2_col2" class="data row2 col2" >Physics</td>
#       <td id="T_0b920_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_0b920_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_0b920_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0b920_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_0b920_row3_col1" class="data row3 col1" >Calculus I</td>
#       <td id="T_0b920_row3_col2" class="data row3 col2" >Mathematics</td>
#       <td id="T_0b920_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_0b920_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_85b87 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_85b87_row0_col0, #T_85b87_row0_col1, #T_85b87_row0_col2, #T_85b87_row0_col3, #T_85b87_row0_col4, #T_85b87_row2_col0, #T_85b87_row2_col1, #T_85b87_row2_col2, #T_85b87_row2_col3, #T_85b87_row2_col4, #T_85b87_row4_col0, #T_85b87_row4_col1, #T_85b87_row4_col2, #T_85b87_row4_col3, #T_85b87_row4_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_85b87_row1_col0, #T_85b87_row1_col1, #T_85b87_row1_col2, #T_85b87_row1_col3, #T_85b87_row1_col4, #T_85b87_row3_col0, #T_85b87_row3_col1, #T_85b87_row3_col2, #T_85b87_row3_col3, #T_85b87_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_85b87">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85b87_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_85b87_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_85b87_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_85b87_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_85b87_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85b87_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85b87_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_85b87_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_85b87_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_85b87_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_85b87_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_85b87_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85b87_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_85b87_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_85b87_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_85b87_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_85b87_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_85b87_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85b87_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_85b87_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_85b87_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_85b87_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_85b87_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_85b87_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85b87_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_85b87_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_85b87_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_85b87_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_85b87_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#     <tr>
#       <th id="T_85b87_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85b87_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_85b87_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_85b87_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_85b87_row4_col3" class="data row4 col3" >enroll</td>
#       <td id="T_85b87_row4_col4" class="data row4 col4" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# #### Test case 4: Student already enrolled

# %% [markdown]
# Current Tables

# %%
track_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_19ab1 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_19ab1_row0_col0, #T_19ab1_row0_col1, #T_19ab1_row0_col2, #T_19ab1_row0_col3, #T_19ab1_row2_col0, #T_19ab1_row2_col1, #T_19ab1_row2_col2, #T_19ab1_row2_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_19ab1_row1_col0, #T_19ab1_row1_col1, #T_19ab1_row1_col2, #T_19ab1_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_19ab1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19ab1_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_19ab1_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_19ab1_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_19ab1_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19ab1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19ab1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_19ab1_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_19ab1_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_19ab1_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_19ab1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19ab1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_19ab1_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_19ab1_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_19ab1_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_19ab1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19ab1_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_19ab1_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_19ab1_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_19ab1_row2_col3" class="data row2 col3" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_5dd19 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_5dd19_row0_col0, #T_5dd19_row0_col1, #T_5dd19_row0_col2, #T_5dd19_row0_col3, #T_5dd19_row0_col4, #T_5dd19_row2_col0, #T_5dd19_row2_col1, #T_5dd19_row2_col2, #T_5dd19_row2_col3, #T_5dd19_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_5dd19_row1_col0, #T_5dd19_row1_col1, #T_5dd19_row1_col2, #T_5dd19_row1_col3, #T_5dd19_row1_col4, #T_5dd19_row3_col0, #T_5dd19_row3_col1, #T_5dd19_row3_col2, #T_5dd19_row3_col3, #T_5dd19_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_5dd19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dd19_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_5dd19_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_5dd19_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_5dd19_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_5dd19_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dd19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5dd19_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5dd19_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_5dd19_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_5dd19_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_5dd19_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5dd19_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5dd19_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_5dd19_row1_col1" class="data row1 col1" >Engineering Design</td>
#       <td id="T_5dd19_row1_col2" class="data row1 col2" >Engineering</td>
#       <td id="T_5dd19_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_5dd19_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5dd19_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5dd19_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5dd19_row2_col1" class="data row2 col1" >Physics I</td>
#       <td id="T_5dd19_row2_col2" class="data row2 col2" >Physics</td>
#       <td id="T_5dd19_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_5dd19_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5dd19_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5dd19_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_5dd19_row3_col1" class="data row3 col1" >Calculus I</td>
#       <td id="T_5dd19_row3_col2" class="data row3 col2" >Mathematics</td>
#       <td id="T_5dd19_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_5dd19_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_0eb99 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_0eb99_row0_col0, #T_0eb99_row0_col1, #T_0eb99_row0_col2, #T_0eb99_row0_col3, #T_0eb99_row0_col4, #T_0eb99_row2_col0, #T_0eb99_row2_col1, #T_0eb99_row2_col2, #T_0eb99_row2_col3, #T_0eb99_row2_col4, #T_0eb99_row4_col0, #T_0eb99_row4_col1, #T_0eb99_row4_col2, #T_0eb99_row4_col3, #T_0eb99_row4_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_0eb99_row1_col0, #T_0eb99_row1_col1, #T_0eb99_row1_col2, #T_0eb99_row1_col3, #T_0eb99_row1_col4, #T_0eb99_row3_col0, #T_0eb99_row3_col1, #T_0eb99_row3_col2, #T_0eb99_row3_col3, #T_0eb99_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_0eb99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0eb99_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_0eb99_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_0eb99_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_0eb99_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_0eb99_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0eb99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0eb99_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0eb99_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_0eb99_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_0eb99_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_0eb99_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_0eb99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0eb99_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_0eb99_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_0eb99_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_0eb99_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_0eb99_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_0eb99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0eb99_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_0eb99_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_0eb99_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_0eb99_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_0eb99_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_0eb99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0eb99_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_0eb99_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_0eb99_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_0eb99_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_0eb99_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#     <tr>
#       <th id="T_0eb99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0eb99_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_0eb99_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_0eb99_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_0eb99_row4_col3" class="data row4 col3" >enroll</td>
#       <td id="T_0eb99_row4_col4" class="data row4 col4" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# Try doing EnrollStudent (5, 3)

# %%
query_stored_procedure_enroll_student(5, 3)
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# The error occurred: Student is already enrolled in this course
# CONTEXT:  PL/pgSQL function enrollstudent(integer,integer) line 51 at RAISE
#
# Connection closed.

# %% [markdown]
# After Operation

# %%
track_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_351be th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_351be_row0_col0, #T_351be_row0_col1, #T_351be_row0_col2, #T_351be_row0_col3, #T_351be_row2_col0, #T_351be_row2_col1, #T_351be_row2_col2, #T_351be_row2_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_351be_row1_col0, #T_351be_row1_col1, #T_351be_row1_col2, #T_351be_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_351be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_351be_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_351be_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_351be_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_351be_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_351be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_351be_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_351be_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_351be_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_351be_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_351be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_351be_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_351be_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_351be_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_351be_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_351be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_351be_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_351be_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_351be_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_351be_row2_col3" class="data row2 col3" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_5268d th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_5268d_row0_col0, #T_5268d_row0_col1, #T_5268d_row0_col2, #T_5268d_row0_col3, #T_5268d_row0_col4, #T_5268d_row2_col0, #T_5268d_row2_col1, #T_5268d_row2_col2, #T_5268d_row2_col3, #T_5268d_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_5268d_row1_col0, #T_5268d_row1_col1, #T_5268d_row1_col2, #T_5268d_row1_col3, #T_5268d_row1_col4, #T_5268d_row3_col0, #T_5268d_row3_col1, #T_5268d_row3_col2, #T_5268d_row3_col3, #T_5268d_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_5268d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5268d_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_5268d_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_5268d_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_5268d_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_5268d_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5268d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5268d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5268d_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_5268d_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_5268d_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_5268d_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5268d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5268d_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_5268d_row1_col1" class="data row1 col1" >Engineering Design</td>
#       <td id="T_5268d_row1_col2" class="data row1 col2" >Engineering</td>
#       <td id="T_5268d_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_5268d_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5268d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5268d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5268d_row2_col1" class="data row2 col1" >Physics I</td>
#       <td id="T_5268d_row2_col2" class="data row2 col2" >Physics</td>
#       <td id="T_5268d_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_5268d_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5268d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5268d_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_5268d_row3_col1" class="data row3 col1" >Calculus I</td>
#       <td id="T_5268d_row3_col2" class="data row3 col2" >Mathematics</td>
#       <td id="T_5268d_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_5268d_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_3d4e5 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_3d4e5_row0_col0, #T_3d4e5_row0_col1, #T_3d4e5_row0_col2, #T_3d4e5_row0_col3, #T_3d4e5_row0_col4, #T_3d4e5_row2_col0, #T_3d4e5_row2_col1, #T_3d4e5_row2_col2, #T_3d4e5_row2_col3, #T_3d4e5_row2_col4, #T_3d4e5_row4_col0, #T_3d4e5_row4_col1, #T_3d4e5_row4_col2, #T_3d4e5_row4_col3, #T_3d4e5_row4_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_3d4e5_row1_col0, #T_3d4e5_row1_col1, #T_3d4e5_row1_col2, #T_3d4e5_row1_col3, #T_3d4e5_row1_col4, #T_3d4e5_row3_col0, #T_3d4e5_row3_col1, #T_3d4e5_row3_col2, #T_3d4e5_row3_col3, #T_3d4e5_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_3d4e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d4e5_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_3d4e5_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_3d4e5_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_3d4e5_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_3d4e5_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d4e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d4e5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3d4e5_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_3d4e5_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_3d4e5_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_3d4e5_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_3d4e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d4e5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_3d4e5_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_3d4e5_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_3d4e5_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_3d4e5_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_3d4e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d4e5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_3d4e5_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_3d4e5_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_3d4e5_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_3d4e5_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_3d4e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d4e5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_3d4e5_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_3d4e5_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_3d4e5_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_3d4e5_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#     <tr>
#       <th id="T_3d4e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d4e5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_3d4e5_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_3d4e5_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_3d4e5_row4_col3" class="data row4 col3" >enroll</td>
#       <td id="T_3d4e5_row4_col4" class="data row4 col4" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# ### Test case 5 : Trigger Error when Deleting a Non-Existing Enrollment Record and Verify EnrollmentLog

# %% [markdown]
# Current tables

# %%
track_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_bfdda th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_bfdda_row0_col0, #T_bfdda_row0_col1, #T_bfdda_row0_col2, #T_bfdda_row0_col3, #T_bfdda_row2_col0, #T_bfdda_row2_col1, #T_bfdda_row2_col2, #T_bfdda_row2_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_bfdda_row1_col0, #T_bfdda_row1_col1, #T_bfdda_row1_col2, #T_bfdda_row1_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_bfdda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfdda_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_bfdda_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_bfdda_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_bfdda_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfdda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bfdda_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bfdda_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_bfdda_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_bfdda_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_bfdda_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bfdda_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_bfdda_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_bfdda_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_bfdda_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_bfdda_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bfdda_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_bfdda_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_bfdda_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_bfdda_row2_col3" class="data row2 col3" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_7d3f8 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_7d3f8_row0_col0, #T_7d3f8_row0_col1, #T_7d3f8_row0_col2, #T_7d3f8_row0_col3, #T_7d3f8_row0_col4, #T_7d3f8_row2_col0, #T_7d3f8_row2_col1, #T_7d3f8_row2_col2, #T_7d3f8_row2_col3, #T_7d3f8_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_7d3f8_row1_col0, #T_7d3f8_row1_col1, #T_7d3f8_row1_col2, #T_7d3f8_row1_col3, #T_7d3f8_row1_col4, #T_7d3f8_row3_col0, #T_7d3f8_row3_col1, #T_7d3f8_row3_col2, #T_7d3f8_row3_col3, #T_7d3f8_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_7d3f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d3f8_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_7d3f8_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_7d3f8_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_7d3f8_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_7d3f8_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d3f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d3f8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7d3f8_row0_col1" class="data row0 col1" >Introduction to Python</td>
#       <td id="T_7d3f8_row0_col2" class="data row0 col2" >Computer Science</td>
#       <td id="T_7d3f8_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_7d3f8_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7d3f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d3f8_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_7d3f8_row1_col1" class="data row1 col1" >Engineering Design</td>
#       <td id="T_7d3f8_row1_col2" class="data row1 col2" >Engineering</td>
#       <td id="T_7d3f8_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_7d3f8_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7d3f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d3f8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7d3f8_row2_col1" class="data row2 col1" >Physics I</td>
#       <td id="T_7d3f8_row2_col2" class="data row2 col2" >Physics</td>
#       <td id="T_7d3f8_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_7d3f8_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7d3f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d3f8_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_7d3f8_row3_col1" class="data row3 col1" >Calculus I</td>
#       <td id="T_7d3f8_row3_col2" class="data row3 col2" >Mathematics</td>
#       <td id="T_7d3f8_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_7d3f8_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_e56da th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_e56da_row0_col0, #T_e56da_row0_col1, #T_e56da_row0_col2, #T_e56da_row0_col3, #T_e56da_row0_col4, #T_e56da_row2_col0, #T_e56da_row2_col1, #T_e56da_row2_col2, #T_e56da_row2_col3, #T_e56da_row2_col4, #T_e56da_row4_col0, #T_e56da_row4_col1, #T_e56da_row4_col2, #T_e56da_row4_col3, #T_e56da_row4_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_e56da_row1_col0, #T_e56da_row1_col1, #T_e56da_row1_col2, #T_e56da_row1_col3, #T_e56da_row1_col4, #T_e56da_row3_col0, #T_e56da_row3_col1, #T_e56da_row3_col2, #T_e56da_row3_col3, #T_e56da_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_e56da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e56da_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_e56da_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_e56da_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_e56da_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_e56da_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e56da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e56da_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e56da_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_e56da_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_e56da_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_e56da_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_e56da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e56da_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e56da_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_e56da_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_e56da_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_e56da_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_e56da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e56da_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e56da_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_e56da_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_e56da_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_e56da_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_e56da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e56da_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e56da_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_e56da_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_e56da_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_e56da_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#     <tr>
#       <th id="T_e56da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e56da_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e56da_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_e56da_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_e56da_row4_col3" class="data row4 col3" >enroll</td>
#       <td id="T_e56da_row4_col4" class="data row4 col4" >2024-11-08 17:18:42.180006</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# Try dropping an enrollment

# %%
trigger_event(1, 1, "drop")
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# The error occurred: The student is not enrolled in the course.
# Connection closed.

# %% [markdown]
# Try enrolling again

# %%
trigger_event(1, 1, "enroll")
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
# Student enrolled successfully in the course.
# Check the updated enrollment log after the event:
#
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_d2b16 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_d2b16_row0_col0, #T_d2b16_row0_col1, #T_d2b16_row0_col2, #T_d2b16_row0_col3, #T_d2b16_row0_col4, #T_d2b16_row2_col0, #T_d2b16_row2_col1, #T_d2b16_row2_col2, #T_d2b16_row2_col3, #T_d2b16_row2_col4, #T_d2b16_row4_col0, #T_d2b16_row4_col1, #T_d2b16_row4_col2, #T_d2b16_row4_col3, #T_d2b16_row4_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_d2b16_row1_col0, #T_d2b16_row1_col1, #T_d2b16_row1_col2, #T_d2b16_row1_col3, #T_d2b16_row1_col4, #T_d2b16_row3_col0, #T_d2b16_row3_col1, #T_d2b16_row3_col2, #T_d2b16_row3_col3, #T_d2b16_row3_col4, #T_d2b16_row5_col0, #T_d2b16_row5_col1, #T_d2b16_row5_col2, #T_d2b16_row5_col3, #T_d2b16_row5_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_d2b16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2b16_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_d2b16_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_d2b16_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_d2b16_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_d2b16_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2b16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2b16_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d2b16_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_d2b16_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_d2b16_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_d2b16_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_d2b16_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2b16_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d2b16_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_d2b16_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_d2b16_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_d2b16_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_d2b16_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2b16_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d2b16_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_d2b16_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_d2b16_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_d2b16_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_d2b16_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2b16_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d2b16_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_d2b16_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_d2b16_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_d2b16_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#     <tr>
#       <th id="T_d2b16_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2b16_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_d2b16_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_d2b16_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_d2b16_row4_col3" class="data row4 col3" >enroll</td>
#       <td id="T_d2b16_row4_col4" class="data row4 col4" >2024-11-08 17:18:42.180006</td>
#     </tr>
#     <tr>
#       <th id="T_d2b16_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2b16_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_d2b16_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_d2b16_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_d2b16_row5_col3" class="data row5 col3" >enroll</td>
#       <td id="T_d2b16_row5_col4" class="data row5 col4" >2024-11-08 17:19:09.983004</td>
#     </tr>
#   </tbody>
# </table>
# Check the updated course capacity after the event:
#
# Courses Table Data:
# <style type="text/css">
# #T_e8160 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_e8160_row0_col0, #T_e8160_row0_col1, #T_e8160_row0_col2, #T_e8160_row0_col3, #T_e8160_row0_col4, #T_e8160_row2_col0, #T_e8160_row2_col1, #T_e8160_row2_col2, #T_e8160_row2_col3, #T_e8160_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_e8160_row1_col0, #T_e8160_row1_col1, #T_e8160_row1_col2, #T_e8160_row1_col3, #T_e8160_row1_col4, #T_e8160_row3_col0, #T_e8160_row3_col1, #T_e8160_row3_col2, #T_e8160_row3_col3, #T_e8160_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_e8160">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8160_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_e8160_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_e8160_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_e8160_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_e8160_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8160_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8160_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_e8160_row0_col1" class="data row0 col1" >Engineering Design</td>
#       <td id="T_e8160_row0_col2" class="data row0 col2" >Engineering</td>
#       <td id="T_e8160_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_e8160_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e8160_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8160_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_e8160_row1_col1" class="data row1 col1" >Physics I</td>
#       <td id="T_e8160_row1_col2" class="data row1 col2" >Physics</td>
#       <td id="T_e8160_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_e8160_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e8160_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8160_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_e8160_row2_col1" class="data row2 col1" >Calculus I</td>
#       <td id="T_e8160_row2_col2" class="data row2 col2" >Mathematics</td>
#       <td id="T_e8160_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_e8160_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8160_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8160_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_e8160_row3_col1" class="data row3 col1" >Introduction to Python</td>
#       <td id="T_e8160_row3_col2" class="data row3 col2" >Computer Science</td>
#       <td id="T_e8160_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_e8160_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.

# %% [markdown]
# Checking any changes in database

# %%
track_database()
# Out:
# Connection to PostgreSQL established successfully.
# Database connection is active.
# Cursor created successfully.
#
# Enrollments Table Data:
# <style type="text/css">
# #T_524c4 th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_524c4_row0_col0, #T_524c4_row0_col1, #T_524c4_row0_col2, #T_524c4_row0_col3, #T_524c4_row2_col0, #T_524c4_row2_col1, #T_524c4_row2_col2, #T_524c4_row2_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_524c4_row1_col0, #T_524c4_row1_col1, #T_524c4_row1_col2, #T_524c4_row1_col3, #T_524c4_row3_col0, #T_524c4_row3_col1, #T_524c4_row3_col2, #T_524c4_row3_col3 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_524c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_524c4_level0_col0" class="col_heading level0 col0" >enrollment_id</th>
#       <th id="T_524c4_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_524c4_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_524c4_level0_col3" class="col_heading level0 col3" >enrollment_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_524c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_524c4_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_524c4_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_524c4_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_524c4_row0_col3" class="data row0 col3" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_524c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_524c4_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_524c4_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_524c4_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_524c4_row1_col3" class="data row1 col3" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_524c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_524c4_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_524c4_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_524c4_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_524c4_row2_col3" class="data row2 col3" >2024-11-08 17:18:42.180006</td>
#     </tr>
#     <tr>
#       <th id="T_524c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_524c4_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_524c4_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_524c4_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_524c4_row3_col3" class="data row3 col3" >2024-11-08 17:19:09.983004</td>
#     </tr>
#   </tbody>
# </table>
# Courses Table Data:
# <style type="text/css">
# #T_0c0fb th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_0c0fb_row0_col0, #T_0c0fb_row0_col1, #T_0c0fb_row0_col2, #T_0c0fb_row0_col3, #T_0c0fb_row0_col4, #T_0c0fb_row2_col0, #T_0c0fb_row2_col1, #T_0c0fb_row2_col2, #T_0c0fb_row2_col3, #T_0c0fb_row2_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_0c0fb_row1_col0, #T_0c0fb_row1_col1, #T_0c0fb_row1_col2, #T_0c0fb_row1_col3, #T_0c0fb_row1_col4, #T_0c0fb_row3_col0, #T_0c0fb_row3_col1, #T_0c0fb_row3_col2, #T_0c0fb_row3_col3, #T_0c0fb_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_0c0fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c0fb_level0_col0" class="col_heading level0 col0" >course_id</th>
#       <th id="T_0c0fb_level0_col1" class="col_heading level0 col1" >course_name</th>
#       <th id="T_0c0fb_level0_col2" class="col_heading level0 col2" >department</th>
#       <th id="T_0c0fb_level0_col3" class="col_heading level0 col3" >max_capacity</th>
#       <th id="T_0c0fb_level0_col4" class="col_heading level0 col4" >course_capacity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c0fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c0fb_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_0c0fb_row0_col1" class="data row0 col1" >Engineering Design</td>
#       <td id="T_0c0fb_row0_col2" class="data row0 col2" >Engineering</td>
#       <td id="T_0c0fb_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_0c0fb_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0c0fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c0fb_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_0c0fb_row1_col1" class="data row1 col1" >Physics I</td>
#       <td id="T_0c0fb_row1_col2" class="data row1 col2" >Physics</td>
#       <td id="T_0c0fb_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_0c0fb_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_0c0fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c0fb_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_0c0fb_row2_col1" class="data row2 col1" >Calculus I</td>
#       <td id="T_0c0fb_row2_col2" class="data row2 col2" >Mathematics</td>
#       <td id="T_0c0fb_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_0c0fb_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0c0fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c0fb_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_0c0fb_row3_col1" class="data row3 col1" >Introduction to Python</td>
#       <td id="T_0c0fb_row3_col2" class="data row3 col2" >Computer Science</td>
#       <td id="T_0c0fb_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_0c0fb_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# EnrollmentLog Table Data:
# <style type="text/css">
# #T_bf2da th {
#   font-weight: bold;
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_bf2da_row0_col0, #T_bf2da_row0_col1, #T_bf2da_row0_col2, #T_bf2da_row0_col3, #T_bf2da_row0_col4, #T_bf2da_row2_col0, #T_bf2da_row2_col1, #T_bf2da_row2_col2, #T_bf2da_row2_col3, #T_bf2da_row2_col4, #T_bf2da_row4_col0, #T_bf2da_row4_col1, #T_bf2da_row4_col2, #T_bf2da_row4_col3, #T_bf2da_row4_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #f9f9f9;
# }
# #T_bf2da_row1_col0, #T_bf2da_row1_col1, #T_bf2da_row1_col2, #T_bf2da_row1_col3, #T_bf2da_row1_col4, #T_bf2da_row3_col0, #T_bf2da_row3_col1, #T_bf2da_row3_col2, #T_bf2da_row3_col3, #T_bf2da_row3_col4, #T_bf2da_row5_col0, #T_bf2da_row5_col1, #T_bf2da_row5_col2, #T_bf2da_row5_col3, #T_bf2da_row5_col4 {
#   text-align: center;
#   border: 1px solid black;
#   color: black;
#   background-color: #e0e0e0;
# }
# </style>
# <table id="T_bf2da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf2da_level0_col0" class="col_heading level0 col0" >log_id</th>
#       <th id="T_bf2da_level0_col1" class="col_heading level0 col1" >student_id</th>
#       <th id="T_bf2da_level0_col2" class="col_heading level0 col2" >course_id</th>
#       <th id="T_bf2da_level0_col3" class="col_heading level0 col3" >action</th>
#       <th id="T_bf2da_level0_col4" class="col_heading level0 col4" >action_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf2da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf2da_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bf2da_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_bf2da_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_bf2da_row0_col3" class="data row0 col3" >enroll</td>
#       <td id="T_bf2da_row0_col4" class="data row0 col4" >2024-11-08 17:18:15.711728</td>
#     </tr>
#     <tr>
#       <th id="T_bf2da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf2da_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_bf2da_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_bf2da_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_bf2da_row1_col3" class="data row1 col3" >enroll</td>
#       <td id="T_bf2da_row1_col4" class="data row1 col4" >2024-11-08 17:18:20.203718</td>
#     </tr>
#     <tr>
#       <th id="T_bf2da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf2da_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_bf2da_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_bf2da_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_bf2da_row2_col3" class="data row2 col3" >enroll</td>
#       <td id="T_bf2da_row2_col4" class="data row2 col4" >2024-11-08 17:18:29.702561</td>
#     </tr>
#     <tr>
#       <th id="T_bf2da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bf2da_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_bf2da_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_bf2da_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_bf2da_row3_col3" class="data row3 col3" >drop</td>
#       <td id="T_bf2da_row3_col4" class="data row3 col4" >2024-11-08 17:18:30.834361</td>
#     </tr>
#     <tr>
#       <th id="T_bf2da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bf2da_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_bf2da_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_bf2da_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_bf2da_row4_col3" class="data row4 col3" >enroll</td>
#       <td id="T_bf2da_row4_col4" class="data row4 col4" >2024-11-08 17:18:42.180006</td>
#     </tr>
#     <tr>
#       <th id="T_bf2da_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bf2da_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_bf2da_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_bf2da_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_bf2da_row5_col3" class="data row5 col3" >enroll</td>
#       <td id="T_bf2da_row5_col4" class="data row5 col4" >2024-11-08 17:19:09.983004</td>
#     </tr>
#   </tbody>
# </table>
# Connection closed.
